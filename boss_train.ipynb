# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
import random

import numpy as np
from sklearn.cross_validation import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.utils import np_utils
from keras.models import load_model
from keras import backend as K

from boss_input import extract_data, resize_with_pad, IMAGE_SIZE


class Dataset(object):

    def __init__(self):
        self.X_train = None
        self.X_valid = None
        self.X_test = None
        self.Y_train = None
        self.Y_valid = None
        self.Y_test = None

    def read(self, img_rows=IMAGE_SIZE, img_cols=IMAGE_SIZE, img_channels=3, nb_classes=2):
        images, labels = extract_data('./data/')
        labels = np.reshape(labels, [-1])
        # numpy.reshape
        X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.1, random_state=random.randint(0, 100))
        X_valid, X_test, y_valid, y_test = train_test_split(images, labels, test_size=0.1, random_state=random.randint(0, 100))
        if K.image_dim_ordering() == 'th':
            X_train = X_train.reshape(X_train.shape[0], 3, img_rows, img_cols)
            X_valid = X_valid.reshape(X_valid.shape[0], 3, img_rows, img_cols)
            X_test = X_test.reshape(X_test.shape[0], 3, img_rows, img_cols)
            input_shape = (3, img_rows, img_cols)
        else:
            X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 3)
            X_valid = X_valid.reshape(X_valid.shape[0], img_rows, img_cols, 3)
            X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 3)
            input_shape = (img_rows, img_cols, 3)

        # the data, shuffled and split between train and test sets
        print('X_train shape:', X_train.shape)
        print(X_train.shape[0], 'train samples')
        print(X_valid.shape[0], 'valid samples')
        print(X_test.shape[0], 'test samples')

        # convert class vectors to binary class matrices
        Y_train = np_utils.to_categorical(y_train, nb_classes)
        Y_valid = np_utils.to_categorical(y_valid, nb_classes)
        Y_test = np_utils.to_categorical(y_test, nb_classes)

        X_train = X_train.astype('float32')
        X_valid = X_valid.astype('float32')
        X_test = X_test.astype('float32')
        X_train /= 255
        X_valid /= 255
        X_test /= 255

        self.X_train = X_train
        self.X_valid = X_valid
        self.X_test = X_test
        self.Y_train = Y_train
        self.Y_valid = Y_valid
        self.Y_test = Y_test
# Out:
# Using Theano backend.

# %%
dataset = Dataset()
dataset.read()
# Out:
# /Users/kent/Documents/notebook/BossSensor/data/boss/20160913_140922.jpg >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/20160917_170513.jpg >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/20160918_081955.jpg >> /User
# boss_input.py:86: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if image == None:
# boss_input.py:52: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if image != None:
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261112.79.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261314.42.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261316.62.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261318.6.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261320.54.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261322.49.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261324.39.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261326.34.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261328.27.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261330.17.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261332.08.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261334.01.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261335.96.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261337.85.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261339.77.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261341.75.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261343.72.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261345.62.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261347.53.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261349.49.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261351.4.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261353.33.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261355.26.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261357.21.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261359.17.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261361.19.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261465.97.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261467.88.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261469.88.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261471.82.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261473.73.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261475.69.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261477.59.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261479.54.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261481.52.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261483.44.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261485.38.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261487.34.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261489.33.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261491.24.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261493.2.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261495.12.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261497.07.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261498.97.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261500.87.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261502.85.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261504.79.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261506.69.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261508.6.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261510.54.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261512.65.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484261514.82.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271829.05.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271830.22.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271831.35.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271832.48.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271833.63.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271834.76.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271835.9.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271837.04.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271838.16.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271839.3.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271840.44.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271841.57.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271842.71.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271885.71.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271886.85.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271934.53.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271936.44.png >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484271938.36.png >> /User
# /Users/kent/Documents/notebook/BossSensor/data/boss/me1484
>> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/other/images(94) >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/other/images(95) >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/other/images(96) >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/other/images(97) >> /User
# /Users/kent/Documents/notebook/BossSensor/data/other/images(98) >> /User
# /Users/kent/Documents/notebook/BossSensor/data/other/images(99) >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/other/images.jpeg >> /User
# face detected
# /Users/kent/Documents/notebook/BossSensor/data/other/jack-ma.jpg >> /User
# face detected
# X_train shape: (300, 3, 64, 64)
# 300 train samples
# 300 valid samples
# 34 test samples

# %%
class Model(object):

    FILE_PATH = './store/model.h5'

    def __init__(self):
        self.model = None

    def build_model(self, dataset, nb_classes=2):
        self.model = Sequential()

        self.model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=dataset.X_train.shape[1:]))
        self.model.add(Activation('relu'))
        self.model.add(Convolution2D(32, 3, 3))
        self.model.add(Activation('relu'))
        self.model.add(MaxPooling2D(pool_size=(2, 2)))
        self.model.add(Dropout(0.25))

        self.model.add(Convolution2D(64, 3, 3, border_mode='same'))
        self.model.add(Activation('relu'))
        self.model.add(Convolution2D(64, 3, 3))
        self.model.add(Activation('relu'))
        self.model.add(MaxPooling2D(pool_size=(2, 2)))
        self.model.add(Dropout(0.25))

        self.model.add(Flatten())
        self.model.add(Dense(512))
        self.model.add(Activation('relu'))
        self.model.add(Dropout(0.5))
        self.model.add(Dense(nb_classes))
        self.model.add(Activation('softmax'))

        self.model.summary()

    def train(self, dataset, batch_size=32, nb_epoch=5, data_augmentation=True):
        # let's train the model using SGD + momentum (how original).
        sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
        self.model.compile(loss='categorical_crossentropy',
                           optimizer=sgd,
                           metrics=['accuracy'])
        if not data_augmentation:
            print('Not using data augmentation.')
            self.model.fit(dataset.X_train, dataset.Y_train,
                           batch_size=batch_size,
                           nb_epoch=nb_epoch,
                           validation_data=(dataset.X_valid, dataset.Y_valid),
                           shuffle=True)
        else:
            print('Using real-time data augmentation.')

            # this will do preprocessing and realtime data augmentation
            datagen = ImageDataGenerator(
                featurewise_center=False,             # set input mean to 0 over the dataset
                samplewise_center=False,              # set each sample mean to 0
                featurewise_std_normalization=False,  # divide inputs by std of the dataset
                samplewise_std_normalization=False,   # divide each input by its std
                zca_whitening=False,                  # apply ZCA whitening
                rotation_range=20,                     # randomly rotate images in the range (degrees, 0 to 180)
                width_shift_range=0.2,                # randomly shift images horizontally (fraction of total width)
                height_shift_range=0.2,               # randomly shift images vertically (fraction of total height)
                horizontal_flip=True,                 # randomly flip images
                vertical_flip=False)                  # randomly flip images

            # compute quantities required for featurewise normalization
            # (std, mean, and principal components if ZCA whitening is applied)
            datagen.fit(dataset.X_train)

            # fit the model on the batches generated by datagen.flow()
            self.model.fit_generator(datagen.flow(dataset.X_train, dataset.Y_train,
                                                  batch_size=batch_size),
                                     samples_per_epoch=dataset.X_train.shape[0],
                                     nb_epoch=nb_epoch,
                                     validation_data=(dataset.X_valid, dataset.Y_valid))

    def save(self, file_path=FILE_PATH):
        print('Model Saved.')
        self.model.save(file_path)

    def load(self, file_path=FILE_PATH):
        print('Model Loaded.')
        self.model = load_model(file_path)

    def predict(self, image):
        if image.shape != (1, 3, IMAGE_SIZE, IMAGE_SIZE):
            image = resize_with_pad(image)
            image = image.reshape((1, 3, IMAGE_SIZE, IMAGE_SIZE))
        image = image.astype('float32')
        image /= 255
        result = self.model.predict_proba(image)
        print(result)
        result = self.model.predict_classes(image)

        return result[0]

    def evaluate(self, dataset):
        score = self.model.evaluate(dataset.X_test, dataset.Y_test, verbose=0)
        print("%s: %.2f%%" % (self.model.metrics_names[1], score[1] * 100))

# %%
model = Model()
model.build_model(dataset)
model.train(dataset, nb_epoch=10)
model.save()

model = Model()
model.load()
model.evaluate(dataset)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_1 (Convolution2D)  (None, 32, 64, 64)    896         convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 32, 64, 64)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 32, 62, 62)    9248        activation_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 32, 62, 62)    0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 32, 31, 31)    0           activation_2[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 32, 31, 31)    0           maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 64, 31, 31)    18496       dropout_1[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 31, 31)    0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 64, 29, 29)    36928       activation_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 64, 29, 29)    0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 64, 14, 14)    0           activation_4[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 64, 14, 14)    0           maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 12544)         0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 512)           6423040     flatten_1[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 512)           0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 512)           0           activation_5[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 2)             1026        dropout_3[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 2)             0           dense_2[0][0]
# ====================================================================================================
# Total params: 6,489,634
# Trainable params: 6,489,634
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# Using real-time data augmentation.
# Epoch 1/10
# 300/300 [==============================] - 11s - loss: 0.4704 - acc: 0.7733 - val_loss: 0.4132 - val_acc: 0.7767
# Epoch 2/10
# 300/300 [==============================] - 10s - loss: 0.4077 - acc: 0.7867 - val_loss: 0.3985 - val_acc: 0.8200
# Epoch 3/10
# 300/300 [==============================] - 10s - loss: 0.3289 - acc: 0.8133 - val_loss: 0.2811 - val_acc: 0.8533
# Epoch 4/10
# 300/300 [==============================] - 10s - loss: 0.3053 - acc: 0.8767 - val_loss: 0.2500 - val_acc: 0.9200
# Epoch 5/10
# 300/300 [==============================] - 10s - loss: 0.2758 - acc: 0.9067 - val_loss: 0.2770 - val_acc: 0.9500
# Epoch 6/10
# 300/300 [==============================] - 10s - loss: 0.2431 - acc: 0.9100 - val_loss: 0.1719 - val_acc: 0.9533
# Epoch 7/10
# 300/300 [==============================] - 10s - loss: 0.3277 - acc: 0.8700 - val_loss: 0.1675 - val_acc: 0.9600
# Epoch 8/10
# 300/300 [==============================] - 10s - loss: 0.2419 - acc: 0.9267 - val_loss: 0.3092 - val_acc: 0.9100
# Epoch 9/10
# 300/300 [==============================] - 10s - loss: 0.2629 - acc: 0.9133 - val_loss: 0.1658 - val_acc: 0.9400
# Epoch 10/10
# 300/300 [==============================] - 11s - loss: 0.1801 - acc: 0.9500 - val_loss: 0.1303 - val_acc: 0.9600
# Model Saved.
# Model Loaded.
# acc: 91.18%

# %%
model.predict()

# %%
from IPython.display import SVG
from keras.utils.visualize_util import model_to_dot

SVG(model_to_dot(model.model).create(prog='dot', format='svg'))

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %matplotlib inline  
import cv2
image = cv2.imread("./data/other/images(1)")
import boss_input

# %%
r = boss_input.extract_face(cv2.imread("./data/other/images(1)"))
# Out:
# face detected

# %%
dataset.X_train
